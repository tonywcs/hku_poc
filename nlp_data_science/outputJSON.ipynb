# %%
from sentence_transformers import SentenceTransformer, util
from sklearn.datasets import fetch_20newsgroups
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.metrics.cluster import contingency_matrix
import spacy
import spacy_universal_sentence_encoder
import datetime

import numpy as np
from joblib import Parallel, delayed
from sklearn.utils import check_random_state
from sklearn.metrics.pairwise import distance_metrics
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity
from joblib import Parallel, delayed
from itertools import combinations

USE_model = spacy_universal_sentence_encoder.load_model('en_use_lg')
Word2Vec_model = spacy.load('en_core_web_lg')
BERT_model = SentenceTransformer('paraphrase-distilroberta-base-v1')

# %%
# custom dataset
def getCSV():
    df = pd.read_csv('custom_dataset.csv', encoding = "mac-roman")
    return df

# SentenceBERT
def getSentenceBERT(text):
    embeddings = BERT_model.encode(text, show_progress_bar=True, convert_to_numpy=True)
    return embeddings

# Clustering Models
def getClustersByThreshold(embeddings, linkageMethod, linkageMetric, threshold):
    clusters = linkage(embeddings, method = linkageMethod, metric = linkageMetric)
    flatClusters = fcluster(clusters, t=threshold, criterion='distance')
    return flatClusters

def evaluation(predictTags, tags, evalMetric):
    print(str(len(set(predictTags))) + " Clusters found.")

    result = {}
    result['Adjusted Rand Score'] = metrics.adjusted_rand_score(predictTags, tags)
    result['Homogenity'] = metrics.homogeneity_completeness_v_measure(predictTags, tags)[0]
    result['Completeness'] = metrics.homogeneity_completeness_v_measure(predictTags, tags)[1]
    result['V Measure'] = metrics.homogeneity_completeness_v_measure(predictTags, tags)[2]
    result_df = pd.DataFrame(data=result, index=[0])
    display(result_df)
    
    c_matrix = contingency_matrix(tags, predictTags)
    print("vertical length: " + str(len(c_matrix)))
    print("horizontal length: "+ str(len(c_matrix[0])))
    print(c_matrix)
    
    return c_matrix, result_df

# %% [markdown]
# # Code to convert result for frontend

# %%
# Generate json
NER = ["PERSON", "NORP", "FAC", "ORG", "GPE", "LOC", "EVENT"]

def getTopNouns(article):
    dic = {}
    for i in range(len(article)):
        doc = Word2Vec_model(article[i])
        for token in doc:
            if token.pos_ == "PROPN" or token.pos_ == "NOUN":
                word = " ".join([t.lemma_ for t in Word2Vec_model(token.text)])
                if word in dic:
                    dic[word] += 1
                else:
                    dic[word] = 1
    dic = sorted(list(dic.items()), key = lambda x: x[1], reverse = True)
    return dic[:10]

def getTopNER(article):
    dic = {}
    for i in range(len(article)):
        doc = Word2Vec_model(article[i])
        for token in doc.ents:
            if token.label_ in NER:
                if token.text in dic:
                    dic[token.text] += 1
                else:
                    dic[token.text] = 1
    dic = sorted(list(dic.items()), key = lambda x: x[1], reverse = True)
    return dic[:10]


def getPrediction(article):
    firstEmbeddings = getSentenceBERT(article)
    firstPrediction = getClustersByThreshold(firstEmbeddings, "complete","cosine", 0.86).tolist()
    
    result = {}
    for i in range(len(firstPrediction)):
        if firstPrediction[i] in result:
            result[firstPrediction[i]].append(firstEmbeddings[i])
        else:
            result[firstPrediction[i]] = [firstEmbeddings[i]]
    result = sorted(list(result.items()), key = lambda x : x[0])
    
    secondEmbeddings = []
    for key, value in result:
        secondEmbeddings.append(np.mean(value, axis = 0))
    
    if len(secondEmbeddings) == 1:
        return firstPrediction
    secondPrediction = getClustersByThreshold(secondEmbeddings, "complete","cosine", 0.86).tolist()
    
    finalPrediction = firstPrediction.copy()
    for i in range(len(finalPrediction)):
        finalPrediction[i] = secondPrediction[firstPrediction[i] - 1]
    
    return finalPrediction

def getJSON(source, date, article, url):
    if len(date) == 0:
        return {"clusters": [], "total_number_of_articles": 0, "total_number_of_clusters": 0}
    elif len(date) == 1:
        prediction = [1]
    else:
        prediction = getPrediction(article)

    result = {}
    for i in range(len(prediction)):
        target = prediction[i]
        if target in result:
            result[target]['total_number_of_articles'] += 1
            result[target]['sources'].append(source[i])
            result[target]['dates'].append(date[i])
            result[target]['articles'].append(article[i])
            result[target]['urls'].append(url[i])
        else:
            result[target] = {
                            "total_number_of_articles": 1,
                            "keywords": [],
                            "sources": [source[i]],
                            "dates": [date[i]],
                            "articles": [article[i]],
                            "urls": [url[i]]}

    json = {"clusters": [], "total_number_of_articles": len(prediction), "total_number_of_clusters": max(prediction)}
    for key, value in result.items():
        value['nounKeywords'] = getTopNouns(value['articles'])
        value['nerKeywords'] = getTopNER(value['articles'])
        json['clusters'].append(value)
    json['clusters'] = sorted(json['clusters'], key=lambda x: x['total_number_of_articles'], reverse = True)
    for i in range(len(json['clusters'])):
        json['clusters'][i]['cluster'] = i + 1
    
    return json

def parseDate(string):
    date = string.split('-')
    year = int(date[0])
    month = int(date[1])
    day = int(date[2])
    return datetime.datetime(year, month, day)


def getAll():
    df = getCSV()
    json = getJSON(list(df['Source']), list(df['Date']), list(df['Title']), list(df['URL']))
    json['cluster_type'] = "all"
    json['date'] = "2021-01-05"
    json['week'] = None
    json['month'] = None
    
    return json
    
def getByMonth(month):
    df = getCSV()
    source = list(df['Source'])
    date = list(df['Date'])
    title = list(df['Title'])
    url = list(df['URL'])
    
    target_source = []
    target_date = []
    target_title = []
    target_url = []
    for i in range(len(date)):
        if int(date[i].split('-')[1]) == month:
            target_source.append(source[i])
            target_date.append(date[i])
            target_title.append(title[i])
            target_url.append(url[i])

    json = getJSON(target_source, target_date, target_title, target_url)
    json['cluster_type'] = "month"
    startDate = parseDate("2021-" + str(month) + "-01")
    json['date'] = startDate.strftime("%Y") + "-" + startDate.strftime("%m") + "-" + startDate.strftime("%d")
    json['week'] = None
    json['month'] = startDate.strftime("%b") + " " + startDate.strftime("%Y")
    
    return json
        
def getByWeek(s):
    startingDay = parseDate(s)
    endingDay = startingDay + datetime.timedelta(days=6)
    
    df = getCSV()
    source = list(df['Source'])
    date = list(df['Date'])
    title = list(df['Title'])
    url = list(df['URL'])
        
    target_source = []
    target_date = []
    target_title = []
    target_url = []
    for i in range(len(date)):
        targetDay = parseDate(date[i])
        if startingDay <= targetDay <= endingDay:
            target_source.append(source[i])
            target_date.append(date[i])
            target_title.append(title[i])
            target_url.append(url[i])
    
    json = getJSON(target_source, target_date, target_title, target_url)
    json['cluster_type'] = "week"
    json['date'] = s
    weekRange = startingDay.strftime("%Y") + "-" + startingDay.strftime("%m") + "-" + startingDay.strftime("%d")
    weekRange += " - "
    weekRange += endingDay.strftime("%Y") + "-" + endingDay.strftime("%m") + "-" + endingDay.strftime("%d")
    json['week'] = weekRange
    json['month'] = None
    
    return json

def getByDay(day):
    df = getCSV()
    source = list(df['Source'])
    date = list(df['Date'])
    title = list(df['Title'])
    url = list(df['URL'])
        
    target_source = []
    target_date = []
    target_title = []
    target_url = []
    for i in range(len(date)):
        if day == date[i]:
            target_source.append(source[i])
            target_date.append(date[i])
            target_title.append(title[i])
            target_url.append(url[i])
    
    json = getJSON(target_source, target_date, target_title, target_url)
    json['cluster_type'] = "day"
    json['date'] = day
    json['week'] = None
    json['month'] = None
    
    return json

# %%
import json
from numpyencoder import NumpyEncoder

months = {"January": 1,
         "February": 2,
         "March": 3}
weeks = ['2021-01-03',
        '2021-01-10',
        '2021-01-17',
        '2021-01-24',
        '2021-01-31',
        '2021-02-07',
        '2021-02-14',
        '2021-02-21',
        '2021-02-28',
        '2021-03-07',
         '2021-03-14',
         '2021-03-21',
         '2021-03-28'
        ]

output = []

#output all
out = getAll()
output.append(out)


#output by month
byMonth = "byMonth/"
for key, value in months.items():
    out = getByMonth(value)
    output.append(out)
    

#output by week
byWeek = "byWeek/"
for startingWeek in weeks:
    out = getByWeek(startingWeek)
    output.append(out)
        
#output by day
byDay = "byDay/"
start = datetime.datetime(2021, 1, 1)
end = datetime.datetime(2021, 4, 1)
while start < end:
    out = getByDay(start.strftime("%Y") + "-" + start.strftime("%m") + "-" + start.strftime("%d"))
    output.append(out)
    start += datetime.timedelta(days=1)
    

with open("outputAsJson.json", 'w') as outfile:
    json.dump(output, outfile, cls=NumpyEncoder)
# Out:
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
out
# Out:
# {'clusters': [{'total_number_of_articles': 215,
#    'keywords': [],
#    'sources': ['Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'Reuters',
#     'Reuters',
#     'Bloomberg',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'The Wall Street Journal',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Bloomberg',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'Reuters',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post',
#     'South China Morning Post'],
#    'dates': ['2021-02-23',
#     '2021-02-10',
#     '2021-03-04',
#     '2021-02-26',
#     '2021-02-14',
#     '2021-02-22',
#     '2021-02-12',
#     '2021-02-16',
#     '2021-02-24',
#     '2021-03-04',
#     '2021-03-02',
#     '2021-02-23',
#     '2021-03-08',
#     '2021-02-14',
#     '2021-03-03',
#     '2021-02-17',
#     '2021-03-08',
#     '2021-03-07',
#     '2021-03-04',
#     '2021-03-07',
#     '2021-02-25',
#     '2021-02-24',
#     '2021-03-07',
#     '2021-02-10',
#     '2021-02-28',
#     '2021-03-03',
#     '2021-03-08',
#     '2021-02-23',
#     '2021-02-19',
#     '2021-03-04',
#     '2021-02-08',
#     '2021-02-09',
#     '2021-02-24',
#     '2021-03-01',
#     '2021-03-01',
#     '2021-02-09',
#     '2021-02-09',
#     '2021-02-21',
#     '2021-03-09',
#     '2021-02-18',
#     '2021-02-24',
#     '2021-02-23',
#     '2021-03-10',
#     '2021-02-11',
#     '2021-03-04',
#     '2021-03-02',
#     '2021-03-14',
#     '2021-03-09',
#     '2021-03-11',
#     '2021-03-15',
#     '2021-03-15',
#     '2021-02-25',
#     '2021-03-03',
#     '2021-03-12',
#     '2021-02-27',
#     '2021-03-15',
#     '2021-02-22',
#     '2021-03-01',
#     '2021-02-18',
#     '2021-02-25',
#     '2021-03-09',
#     '2021-03-05',
#     '2021-03-12',
#     '2021-03-10',
#     '2021-02-23',
#     '2021-03-05',
#     '2021-02-24',
#     '2021-03-10',
#     '2021-03-08',
#     '2021-03-04',
#     '2021-02-27',
#     '2021-02-26',
#     '2021-02-27',
#     '2021-03-10',
#     '2021-03-12',
#     '2021-02-25',
#     '2021-03-06',
#     '2021-03-12',
#     '2021-02-21',
#     '2021-03-11',
#     '2021-03-09',
#     '2021-03-13',
#     '2021-03-05',
#     '2021-03-12',
#     '2021-03-01',
#     '2021-03-02',
#     '2021-03-06',
#     '2021-03-04',
#     '2021-03-10',
#     '2021-03-12',
#     '2021-02-22',
#     '2021-02-25',
#     '2021-03-15',
#     '2021-03-11',
#     '2021-02-26',
#     '2021-02-19',
#     '2021-03-08',
#     '2021-02-19',
#     '2021-02-20',
#     '2021-02-17',
#     '2021-03-14',
#     '2021-02-25',
#     '2021-02-24',
#     '2021-03-12',
#     '2021-02-23',
#     '2021-03-10',
#     '2021-02-22',
#     '2021-02-22',
#     '2021-02-26',
#     '2021-03-12',
#     '2021-03-10',
#     '2021-03-11',
#     '2021-03-13',
#     '2021-03-10',
#     '2021-03-09',
#     '2021-03-11',
#     '2021-03-10',
#     '2021-03-08',
#     '2021-03-10',
#     '2021-03-06',
#     '2021-03-10',
#     '2021-02-28',
#     '2021-03-06',
#     '2021-03-12',
#     '2021-02-27',
#     '2021-03-13',
#     '2021-03-12',
#     '2021-02-23',
#     '2021-03-14',
#     '2021-03-14',
#     '2021-02-22',
#     '2021-02-19',
#     '2021-03-08',
#     '2021-02-14',
#     '2021-02-17',
#     '2021-02-23',
#     '2021-02-27',
#     '2021-02-25',
#     '2021-02-23',
#     '2021-03-10',
#     '2021-02-20',
#     '2021-03-09',
#     '2021-03-09',
#     '2021-03-01',
#     '2021-02-14',
#     '2021-03-05',
#     '2021-02-05',
#     '2021-03-15',
#     '2021-03-12',
#     '2021-03-11',
#     '2021-03-11',
#     '2021-03-17',
#     '2021-03-17',
#     '2021-03-15',
#     '2021-03-15',
#     '2021-03-16',
#     '2021-03-12',
#     '2021-03-10',
#     '2021-03-11',
#     '2021-03-09',
#     '2021-03-02',
#     '2021-03-04',
#     '2021-03-08',
#     '2021-03-16',
#     '2021-03-03',
#     '2021-03-11',
#     '2021-03-06',
#     '2021-03-03',
#     '2021-03-02',
#     '2021-02-23',
#     '2021-02-24',
#     '2021-03-04',
#     '2021-02-17',
#     '2021-02-25',
#     '2021-03-04',
#     '2021-03-01',
#     '2021-03-17',
#     '2021-03-17',
#     '2021-03-16',
#     '2021-03-16',
#     '2021-03-16',
#     '2021-03-15',
#     '2021-03-12',
#     '2021-03-15',
#     '2021-03-02',
#     '2021-03-15',
#     '2021-03-04',
#     '2021-03-05',
#     '2021-02-22',
#     '2021-03-11',
#     '2021-03-03',
#     '2021-02-23',
#     '2021-03-02',
#     '2021-02-26',
#     '2021-02-17',
#     '2021-02-24',
#     '2021-03-05',
#     '2021-02-17',
#     '2021-02-19',
#     '2021-03-17',
#     '2021-03-17',
#     '2021-03-16',
#     '2021-03-16',
#     '2021-03-16',
#     '2021-03-16',
#     '2021-03-15',
#     '2021-03-17',
#     '2021-03-15',
#     '2021-03-15',
#     '2021-03-16',
#     '2021-03-13',
#     '2021-03-13',
#     '2021-03-13',
#     '2021-03-02',
#     '2021-03-14'],
#    'articles': ['State offers loan support to foreign buyers of UK goods',
#     'UK stocks creep back into favour after years of ‘benign neglect’',
#     'US suspends tariffs on UK exports in Airbus-Boeing trade dispute',
#     'Cancer drug is first to begin fast-track UK approval process',
#     'Private equity firms eye UK stock market for cheaper deals',
#     'Should the UK change its listing rules to attract more overseas companies?',
#     'Is the party over for top tech stocks?',
#     'China targets rare earth export curbs to hobble US defence industry',
#     'Hong Kong expects economic recovery this year',
#     'US vs China: Biden bets on alliances to push back against Beijing',
#     'Chinese electric carmaker Nio warns of hit from global chip shortage ',
#     'Tech stocks on the slide',
#     'Japan’s SBI plans Hong Kong pullout on concerns over security law  ',
#     'Hong Kong plans stricter money laundering checks on Chinese officials',
#     'Hong Kong energy fund sues Japan in groundbreaking case',
#     'Hong Kong stock trading volumes jump to four times those of LSE',
#     'Hong Kong residents fall ill after jabs',
#     'More vaccines arrive in Hong Kong ',
#     'Hong Kong dropped from economic freedom index after crackdown ',
#     'China turns its back on Hong Kong loyalists ',
#     'Hong Kong spending coupons to boost GDP',
#     'Hong Kong expects economic recovery this year',
#     'China set to cut proportion of directly elected lawmakers in Hong Kong',
#     'Letter: Hong Kong’s role as a hub for arbitration is growing',
#     'Hong Kong and Macau receive first jab shipments',
#     'Hong Kong defends delay in reporting death of vaccinated man',
#     'Life in the UK is not easy for former Hong Kong residents',
#     'More than 40,000 sign up for vaccinations in Hong Kong',
#     'Hong Kong revamp of public broadcaster renews press freedom fears',
#     'Asian stocks fall as inflation worries stalk markets',
#     'UK says Hong Kong authorities no longer recognise dual nationality',
#     'Hong Kong biotech sector booms on buoyant markets and pandemic',
#     'Shares in Hong Kong bourse operator plunge as city increases trading tax',
#     'Hong Kong protesters defy ban to show support for detained leaders',
#     'Hong Kong to overhaul Hang Seng to reflect Chinese listing boom',
#     'Hong Kong stock exchange names JPMorgan banker as chief executive',
#     'BlackRock’s new Asia-Pacific chief sees Hong Kong retaining power  ',
#     'Pro-Beijing reforms threaten ‘end’ of HK’s legal system, top lawyer warns ',
#     'HK-listed groups badly lag behind global peers on women directors ',
#     'Hong Kong’s historic businesses face an uncertain future',
#     'HK stamp duty: hardly taxing',
#     'China urges Biden to lift sanctions and stop meddling  ',
#     'US and China lay groundwork for first high-level meeting under Biden',
#     'Biden creates Pentagon task force on China',
#     'US vs China: Biden bets on alliances to push back against Beijing',
#     'China’s trade hand remains strong post-Trump',
#     'Max Hastings: China Might Defeat America In War Over Taiwan',
#     "China Generals Urge More Spending for U.S. Conflict 'Trap'",
#     'U.S., China Envoys to Hold First In-Person Meeting in Alaska',
#     'Biden Envoys Kick Off Asian Allies Visit to Build Unity on China',
#     "Technology Continues to be Sensitive Area in U.S.-China Ties, E.A.I's Hofman Says",
#     'India Is a Flashpoint in the China-U.S. Cold War',
#     'China Revs Up Grand Chip Ambitions to Counter U.S. Blacklistings',
#     "China Hits Out at New Huawei Curbs, Says U.S. Can't Be Trusted",
#     "Bloomberg New Economy: On the Path to China-US 'Decoupling'",
#     'China to Pour More Money Into Chips, AI, 5G to Catch U.S.',
#     'Germany, Philippines, India, Djibouti May Decide US-China Cold War',
#     'Biden Putting Tech, Not Troops, at Core of U.S.-China Policy',
#     'China Decoupling Would Cost U.S. Billions, Chamber Says',
#     'China Says Biden Bid to Shift U.S. Supply Chains Unrealistic',
#     "China's Microsoft, Russia's SolarWinds Hacks Could Overwhelm US",
#     'China Seeks to Boost Trade With U.S. Allies, Premier Li Says',
#     'U.S. Imposes New 5G License Limits on Some Huawei Suppliers',
#     'China, U.S. Top Diplomats Eye Alaska Meeting: SCMP',
#     'Germany Is a Flashpoint in the U.S.-China Cold War',
#     "China's 'Peace Cable' in Europe Raises Tensions With the US",
#     'The Philippines Is a Flashpoint in the U.S.-China Cold War',
#     'U.S. Cites Threat to Carriers From Chinese Anti-Ship Missile',
#     'NPC Report: China to Speed Up Legislation to Fight US Sanctions',
#     'What to Watch as China Rolls Out an Economic Plan to Overtake the U.S.',
#     'Djibouti Is a Flashpoint in the U.S.-China Cold War',
#     'Biden Trade Pick Says China Must Deliver on Phase-One Pact',
#     'U.S. Signals It Will Implement Rule Curbing China Tech Threats',
#     'India to Buy First U.S. Armed Drones to Counter China, Pakistan',
#     'Biden Steers Off a Blunt Anti-China Message With Asian Allies',
#     'China Says It Never Asked U.S. Diplomats to Take Anal Swab Tests',
#     'U.S. Extends Tariff Exclusion on China Virus Supplies 6 Months',
#     'U.S. condemns China at UN rights forum for abuse of Uighurs, Tibetans',
#     "China calls for a reset, but U.S. says Beijing trying to 'avert blame'",
#     'China semiconductor trade association establishes work group with U.S. counterpart',
#     "China says hopes U.S. will remove 'unreasonable' curbs on cooperation",
#     'Five Chinese companies pose threat to U.S. national security: FCC',
#     "China says to promote U.S. business ties on basis of 'mutual respect'",
#     "U.S. criticises China's Hong Kong move, set to raise Xinjiang genocide charge in talks",
#     'China, U.S. should lift COVID-19 travel bans if herd immunity reached, Chinese epidemiologist says',
#     'U.S. doubles down on protecting university research from China',
#     "U.S. condemns China's Hong Kong moves, working to 'galvanize' action against abuses",
#     "Biden administration singles out China as 'biggest geopolitical test' for U.S",
#     "U.S. says no change in its genocide determination for China's Xinjiang",
#     'China warns U.S. to stay out of Hong Kong affairs ahead of Alaska meet',
#     'China says China, U.S. and Europe should work together to uphold multilateralism',
#     'China denies requiring U.S. diplomats to take anal swab tests',
#     'U.S. urges Paraguay to work with Taiwan amid pandemic protests',
#     'Top U.S., China diplomats to hold first in-person talks of Biden presidency',
#     "U.S. has not made 'final decision' on participating in Olympics in China",
#     "U.S. House revives bill to ban goods from China's Xinjiang",
#     'Game of drones: Chinese giant DJI hit by U.S. tensions, staff defections',
#     'Yellen says U.S. will keep tariffs on China in place for now',
#     'U.S. lawmakers set resolution condemning China over Hong Kong rights',
#     'U.S. ship sails in South China Sea by China-claimed islands',
#     'Singapore PM sees considerable risk of severe U.S.-China tensions -BBC interview',
#     'China says U.S. undermining stability after U.S. warship sails through Taiwan Strait',
#     'Top U.S. Senate Democrat directs lawmakers to craft bill to counter China',
#     "China to try two Canadians charged with espionage 'soon': Global Times",
#     "China's yuan firms on dollar weakness after Powell testimony",
#     'Mexico leans on China after Biden rules out vaccines sharing in short term',
#     "Chinese spyware code was copied from America's NSA: researchers",
#     'Chinese ambassador to U.S. says the two countries must define policy boundaries',
#     'China will extend tariff exemptions for 65 U.S. products',
#     'Hong Kong stocks end week lower on Sino-U.S. tensions',
#     'U.S. Senate panel chairman hopes for vote on China measures as soon as April',
#     '\nTop U.S., China Officials to Meet Next Week in Alaska on Range of Issues',
#     'U.S. Wants India’s Help on China, but There Are a Few Sticking Points',
#     'U.S and China Engage, Tentatively, on Climate Change',
#     'U.S. Companies in China Say Political Tensions Remain Top Concern',
#     'Massive Hacks Linked to Russia, China Exploited U.S. Internet Security Gap',
#     'China’s Rise Drives a U.S. Experiment in Industrial Policy',
#     'China Targets AI, Chips Among Seven Battlefronts in Tech Race With U.S.',
#     'For U.S. Farmers, China Is Back and Bigger Than Ever',
#     'U.S. Blacklisted China’s Xiaomi Because of Award Given to Its Founder',
#     'America Wakes Up to the China Threat',
#     'U.S. Enlists Allies to Counter China’s Technology Push',
#     'China-Linked Hack Hits Tens of Thousands of U.S. Microsoft Customers',
#     'China Manufacturing Stumbles as U.S. Takes Off',
#     'U.S. to Impose Sweeping Rule Aimed at China Technology Threats',
#     'Why Authoritarian China Loves Woke U.S.',
#     'U.S. to Take Hard Line on Chinese Trade Practices, Administration Says',
#     'China Faces European Obstacles as Some Countries Heed U.S. Pressure',
#     'Americans’ Views on China Go From Bad to Worse',
#     'China Taps U.S.-Trained Former Central Banker for IMF Role',
#     'China Deploys Covid-19 Vaccine to Build Influence, With U.S. on Sidelines',
#     'Underfunded and Under Pressure, U.S. Pensions to Keep Investing in China',
#     '\nOpinion: The Woke Chinese Communist Party',
#     'U.S. Expresses ‘Deep Concerns’ Over China Withholding Data From Pandemic Investigators',
#     'Decoupling With China Would Hurt U.S. Businesses, Chamber of Commerce Says',
#     'How American Free Trade Can Outdo China',
#     'Cold War-Era Defense System to Get Upgrade to Counter Russia, China',
#     'CIA Nominee Burns Promises Spying Focus on China, Seeing ‘Adversarial, Predatory’ Regime',
#     'How Xi Jinping Is Reshaping China and What It Means for the West',
#     'Wuhan Lab Theory a Dark Cloud on China',
#     'Biden Defends Democracy at Summits With European Allies, Seeing China as ‘Stiff’ Competition',
#     'What Would Reagan Say Now About the Chinese Communist Party?',
#     'Why China Worries About Losing Manufacturing',
#     "China's furtive bitcoin trade heats up again, worrying regulators",
#     "Japan's SBI in talks to set up cryptocurrency JV with foreign financial firms",
#     'China Vows to Boost Car Sales, EV Charging Facilities',
#     'Kia Seeks Partners to Build Apple Car in Georgia',
#     'China Targets Hong Kong Wealth Gap, Housing Woes After Political Purge',
#     'China All but Ends Hong Kong Democracy With ‘Patriots Only’ Rule',
#     'Facebook Drops Plan to Run Fiber Cable to Hong Kong Amid U.S. Pressure',
#     'Hong Kong Deserves to Be in Freedom Index',
#     'HSBC Closes Main Hong Kong Office After Multiple Covid Cases',
#     "Jack Ma's SCMP Joins Hong Kong Media Groups Facing China Control",
#     'China Slams U.K., Says It Has No Right to Supervise Hong Kong',
#     'Covid Lockdown News: Hong Kong Steps Up Expat Testing',
#     'Hong Kong Unemployment Climbs to Highest Since March 2004',
#     'Hong Kong Sends Class of 8-Year-Olds to Government Quarantine',
#     'China Remakes Hong Kong in Its Own Image, Starting With New Election Rules',
#     'Hong Kong Vaccine No-Show Rate Up After Side-Effect Reports',
#     "Hong Kong Minister Warns Against 'Oblivious' Criticism of China",
#     'HK Security Hearing Adjourned After Activist Collapses in Court',
#     'Hong Kong Dumped From Economic Freedom List It Had Dominated',
#     'Is It Legal to Criticize the Communist Party in Hong Kong?',
#     'Inside Hong Kong Quarantine',
#     'Hong Kong Makes 100th Arrest Using National Security Law',
#     "China Squashes Hong Kong Protesters' Dissent With Security Law",
#     "Hong Kong's Trusted Independent Judiciary Approaches Its Twilight",
#     'Hong Kong House Costs a Record $2 Million a Year to Rent',
#     'Hong Kong Explores SPAC Listings to Get In on Deal Boom',
#     'Chinese Official Signals Changes to Hong Kong Election Rules',
#     'Hong Kong Budget: Winners and Losers From $15.5 Billion Stimulus',
#     "Marathon Hong Kong Security Law Hearing Slammed as 'Farce'",
#     "Hong Kong Leader's Approval Rating Falls to Lowest Since Sept.",
#     'Market News: Hong Kong Stamp Duty Hike, First Since 1993, Shocks Traders',
#     'Preserving Hong Kong Element is Key to Hang Seng, Compiler Says',
#     "Hong Kong's Property Crisis Has No Easy Solutions",
#     'U.S. agency criticizes Hong Kong air carrier quarantine rules',
#     'Not all deadwood: Furniture fashioned from Hong Kong tree waste',
#     'Hong Kong shares tick higher on tech, consumer boost',
#     'Concerns mount that new Hong Kong law on patriotic oaths could trap judges',
#     "Hong Kong's tough COVID-19 rules see babies isolated, families cramped in tiny spaces",
#     'Hong Kong widens vaccine scheme to people over 30, domestic helpers',
#     "U.S. criticises China's Hong Kong move, set to raise Xinjiang genocide charge in talks",
#     'Hong Kong court grants bail to three more activists in subversion case',
#     "China's electoral reform 'earthquake' set to upend Hong Kong politics",
#     'HK scientist develops retinal scan technology to identify early childhood autism',
#     "Hong Kong dropped from Economic Freedom Index as policies 'controlled from Beijing'",
#     'What is love? Beijing desires unconditional loyalty from Hong Kong',
#     "Hong Kong leader gets China's Sinovac vaccine to bolster public confidence",
#     'China stocks jump on upbeat lending data, Hong Kong tracks Wall Street rally',
#     'Former Hong Kong chief C.Y. Leung does not rule out return to post',
#     'Hong Kong plans lower budget deficit as economy expected to recover',
#     'Hong Kong considering allowing SPAC listings',
#     'Exclusive: Two rights groups quit Hong Kong as security law sends shudders through NGOs',
#     "Hong Kong approves China's Sinovac vaccine, rollout from February 26",
#     'Nearly 5,000 Hong Kong citizens sign up for new UK visa: The Times',
#     "China eyes change in how Hong Kong's chief executive is chosen, official says",
#     'Hong Kong tycoon Jimmy Lai arrested again while in jail, papers say',
#     'Hong Kong signals overhaul of public broadcaster RTHK, stoking media freedom concerns',
#     "Hong Kong's dead trees find new life as furniture",
#     "China 'getting close' to southbound Bond Connect",
#     'Asian stocks retreat as investors await Fed',
#     'Hong Kong hints at new plan to bring home residents stranded in Britain',
#     'Parents question ‘cruel’ policy that put 120 young people in Hong Kong quarantine',
#     'US objects to Hong Kong quarantine rules, warns it could restrict Cathay flights',
#     'Hong Kong expands coronavirus vaccines to 5.5 million people',
#     'Vacancy rates of Hong Kong street shops stabilise as eateries move into trendy districts',
#     'HKMA sees mega IPOs stemming currency slide as Kyle Bass tweets peg demise',
#     'Covid-19 shaming in Hong Kong needs to stop',
#     'Luxury industrial building in Tuen Mun targets Hong Kong’s creative types',
#     'Hong Kong’s hi-tech ambitions threatened by shortage of skilled talent',
#     'EU’s annual Hong Kong report hits out at ‘severe erosion of autonomy’',
#     'Reforms have shattered Hong Kong’s democratic dream',
#     'These are the Canadians who say they will never return to Hong Kong',
#     'Plan to be finalised ‘by May’ for Beijing overhaul of Hong Kong elections system'],
#    'urls': ['http://www.ft.com/content/e890b877-e75b-4e54-a066-b6d7b3dc59e5',
#     'http://www.ft.com/content/442e7d88-4d5e-4251-95ae-950077b70b39',
#     'http://www.ft.com/content/f4844a11-2fef-4150-a64b-986bdf244161',
#     'http://www.ft.com/content/bd80b394-ac49-41ca-aee3-8933fd7c0da9',
#     'http://www.ft.com/content/1f0d04f7-3ea6-4c19-8afe-2cf76898e3a3',
#     'http://www.ft.com/content/cf2a6090-c843-4310-af81-f45874f53014',
#     'http://www.ft.com/content/6d2fafc0-e913-4e63-b9b6-e04eba0ad858',
#     'http://www.ft.com/content/d3ed83f4-19bc-4d16-b510-415749c032c1',
#     'http://www.ft.com/content/7894d260-be51-4a91-b344-31656ccd961e',
#     'http://www.ft.com/content/cf71feb2-297f-4e3a-8627-b89931cc6a80',
#     'http://www.ft.com/content/e0e1c055-c525-4d11-b420-c7f8c7c8f493',
#     'http://www.ft.com/content/f878d573-fc4b-415a-b6dc-a993ad8ce4ae',
#     'http://www.ft.com/content/84919df6-2565-4291-968e-00aff21377f5',
#     'http://www.ft.com/content/2d468971-eedd-4903-b1e1-9335994aaebb',
#     'http://www.ft.com/content/155da1d7-075e-4122-adec-1e4fec51f582',
#     'http://www.ft.com/content/c324674c-c91e-427e-82c5-87a7e9a53bab',
#     'http://www.ft.com/content/ece57cb4-77a2-4490-bebf-128e0aafdad9',
#     'http://www.ft.com/content/b65b0ab8-fb80-4d83-bc38-1f91853cf818',
#     'http://www.ft.com/content/c50ad498-c7ff-4e68-9f5f-c66ca1a62183',
#     'http://www.ft.com/content/c29b6bb6-b1b7-4b15-a115-bc20d741b3f9',
#     'http://www.ft.com/content/286879cc-8ab9-4095-bc77-2001521b537d',
#     'http://www.ft.com/content/7894d260-be51-4a91-b344-31656ccd961e',
#     'http://www.ft.com/content/b4cb2c31-7f31-41e7-a088-29113c611152',
#     'http://www.ft.com/content/9a63409c-fbb2-4198-9061-adee1d309a9c',
#     'http://www.ft.com/content/7ac01de3-cf4b-420b-abf0-e8fed54a3e33',
#     'http://www.ft.com/content/3729a1d1-c43e-4617-9a42-977ac6813ee5',
#     'http://www.ft.com/content/599deb6f-6184-4a22-b518-280017ecc9d0',
#     'http://www.ft.com/content/36d3c6f1-ddb6-4fcc-8d3c-15a6d5ceb1c9',
OrwM?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiECjOo2qCTcEQPcIfuK-H9toqGQgEKhAIACoHCAow4uzwCjCF3bsCMIrOrwM?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiEHDjM0eyzwqbSrjwi8N6KJsqGAgEKg8IACoHCAow1tzJATDnyxUww8rPBg?hl=en-US&gl=US&ceid=US%3Aen'],
#    'nounKeywords': [('bitcoin', 38),
#     ('cryptocurrency', 14),
#     ('crypto', 9),
#     ('China', 8),
#     ('cryptocurrencie', 6),
#     ('money', 5),
#     ('Coinbase', 5),
#     ('market', 5),
#     ('price', 5),
#     ('bank', 4)],
#    'nerKeywords': [('China', 8),
#     ('US', 4),
#     ('Coinbase', 3),
#     ('SEC', 3),
#     ('UK', 2),
#     ('Bitcoin’s', 2),
#     ('Dogecoin', 2),
#     ('Tether', 2),
#     ('Bitfinex', 2),
#     ('New York', 2)],
#    'cluster': 4},
#   {'total_number_of_articles': 25,
#    'keywords': [],
#    'sources': ['Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Reuters',
#     'Bloomberg'],
#    'dates': ['2021-02-11',
#     '2021-02-15',
#     '2021-02-19',
#     '2021-02-11',
#     '2021-03-04',
#     '2021-02-25',
#     '2021-02-10',
#     '2021-03-08',
#     '2021-02-11',
#     '2021-02-19',
#     '2021-03-08',
#     '2021-02-17',
#     '2021-03-02',
#     '2021-02-23',
#     '2021-03-01',
#     '2021-02-11',
#     '2021-02-09',
#     '2021-02-12',
#     '2021-03-01',
#     '2021-03-02',
#     '2021-02-19',
#     '2021-02-24',
#     '2021-02-11',
#     '2021-02-22',
#     '2021-03-10'],
#    'articles': ['Amsterdam punctures City’s post-Brexit hopes',
#     'Euronext/Brexit: the Italian job',
#     'Johnson’s plan to safeguard the union in chaos as key aide quits',
#     'Amsterdam as trading hub, Italy’s recovery fund ',
#     'What independence movements teach us about belonging',
#     'Johnson reshapes chaotic strategy to combat Scottish independence',
#     'Amsterdam ousts London as Europe’s top share trading hub',
#     'Johnson set to unnerve allies with ‘Global Britain’ defence review',
#     'Securities trading/City of London: end of the Golden Age',
#     'Letter: Applying for jobs should not be so humiliating',
#     'Why the WTO should judge less, lest it be judged',
#     'European bankers set sights on Amsterdam as Spac centre',
#     'Letter: Scotland’s independence drive is no flash in the pan',
#     'Inside the split threatening Scotland’s independence campaign',
#     'Vaccine dispute suggests a new role for the WTO',
#     'Trade-phobic governments may be jumping at electoral shadows',
#     'Sweden flies the flag for the free-trade cause in the EU',
#     'Covid variants and new advisers curb Boris Johnson’s natural optimism',
#     'Who is winning the race to be the European Robinhood?',
#     'A pivotal moment for Scotland’s independence champion ',
#     'Investing in Europe — new opportunities on the old continent',
#     'Hedge funds’ bitcoin trade helps lift Grayscale assets to $38bn ',
#     'Securities trading/City of London: end of the Golden Age',
#     "Factbox: What are NFTs and who's cashing in on them?",
#     'Gaming Crypto-Artists Court Controversy While Cashing in on NFTs'],
#    'urls': ['http://www.ft.com/content/79f231fe-3c39-41ca-9c33-6713b1834f76',
#     'http://www.ft.com/content/581a3ed2-3b91-4220-802e-3bf663ade005',
#     'http://www.ft.com/content/1173b4ff-1875-41c6-9b8f-5891e312fc96',
#     'http://www.ft.com/content/12e847c4-9f9b-454f-8050-185025589406',
#     'http://www.ft.com/content/729fcaa4-05f4-4ec3-81b9-3eb3083e66f5',
#     'http://www.ft.com/content/18f8a459-ba52-4c3c-856e-cff9f7ad9b93',
#     'http://www.ft.com/content/3dad4ef3-59e8-437e-8f63-f629a5b7d0aa',
#     'http://www.ft.com/content/4a002266-21ee-495e-83c6-7baeebffdd52',
#     'http://www.ft.com/content/e018eb25-8724-4553-8b3c-bc73cd928080',
#     'http://www.ft.com/content/b5d7b1d6-1116-42f2-901a-037a0afc7372',
#     'http://www.ft.com/content/0314b810-cf50-4412-aa39-6aefbb260d8f',
#     'http://www.ft.com/content/240293a8-20ed-4cf3-a5ec-63dc1c2d9076',
#     'http://www.ft.com/content/bc4e6fd5-273e-4efc-8b28-52402f949187',
#     'http://www.ft.com/content/2b88ed4d-9857-44e8-b191-3fd577ae76e6',
#     'http://www.ft.com/content/020c5a53-b27c-4faf-bda8-687763f92585',
#     'http://www.ft.com/content/25683c03-eb55-48d8-9e34-af75684d7858',
#     'http://www.ft.com/content/ab686b77-df7d-4ac5-be6d-01430d6212de',
#     'http://www.ft.com/content/9ca92244-b3c7-4845-b44e-1619d45c7177',
#     'http://www.ft.com/content/201cbe4d-ae19-4b60-8693-c20127fbf3ec',
#     'http://www.ft.com/content/8baea3ed-72fb-4162-a52c-ac3a8174ca42',
#     'http://www.ft.com/content/44d8382b-6743-4a72-b1ce-e0a7081a1795',
#     'http://www.ft.com/content/a341f9f7-887e-41c1-9748-8d0025f23085',
#     'http://www.ft.com/content/e018eb25-8724-4553-8b3c-bc73cd928080',
#     'https://news.google.com/articles/CBMiPWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2FydGljbGUvY3J5cHRvLWN1cnJlbmN5LWlkVVNMOE4yS1MySTLSATRodHRwczovL21vYmlsZS5yZXV0ZXJzLmNvbS9hcnRpY2xlL2FtcC9pZFVTTDhOMktTMkky?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiEHWiw_2ApcRW4lpL9zJXAG4qGQgEKhAIACoHCAow4uzwCjCF3bsCMNGAygM?hl=en-US&gl=US&ceid=US%3Aen'],
#    'nounKeywords': [('trade', 7),
#     ('independence', 5),
#     ('Amsterdam', 4),
#     ('Johnson', 4),
#     ('city', 3),
#     ('London', 3),
#     ('Scotland', 3),
#     ('Brexit', 2),
#     ('job', 2),
#     ('hub', 2)],
#    'nerKeywords': [('Amsterdam', 4),
#     ('Johnson', 3),
#     ('Scotland', 3),
#     ('Europe', 2),
#     ('City of London', 2),
#     ('WTO', 2),
#     ('City', 1),
#     ('post-Brexit', 1),
#     ('Euronext/Brexit', 1),
#     ('Italian', 1)],
#    'cluster': 5},
#   {'total_number_of_articles': 11,
#    'keywords': [],
#    'sources': ['Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Reuters',
#     'Reuters',
#     'Bloomberg',
#     'Bloomberg',
#     'South China Morning Post'],
#    'dates': ['2021-03-03',
#     '2021-02-10',
#     '2021-02-25',
#     '2021-02-25',
#     '2021-03-01',
#     '2021-03-01',
#     '2021-03-05',
#     '2021-02-16',
#     '2021-03-14',
#     '2021-03-01',
#     '2021-03-16'],
#    'articles': ['Labour accuses Sunak of failing to address ‘deep-rooted inequality’ ',
#     'Labour’s Starmer has no quick fix; Johnson stole his story',
#     'Coinbase’s offering docs have just dropped [Update]',
#     'Craig Wright is taking legal action to recover $3.5bn of “stolen bitcoin”',
#     'Sunak previews UK budget, von der Leyen warns of more pandemics, Lucid takes on Tesla',
#     'Hang Seng index: all shook up',
#     'Blockchain firm Ripple sees no fallout in Asia Pacific from SEC lawsuit',
#     'At the heart of the SEC’s case against Ripple, a dispute over legal advice',
#     'Market Manipulation Chatter Rises as Digital Art Scene Explodes',
#     'Hang Seng Index Poised for Biggest Overhaul in 51 Years',
#     'New RTHK boss confirms he axed several episodes of shows over lack of balance'],
#    'urls': ['http://www.ft.com/content/44405972-0eba-47da-a927-39fbf8ec1d2e',
#     'http://www.ft.com/content/460fdc6b-b5d5-4276-92ae-b8b6f6386590',
#     'http://www.ft.com/content/410e8cdf-8ed9-47ee-87c4-2709f077be54',
#     'http://www.ft.com/content/56ba5a61-367e-4b10-abc8-4f79bab4144d',
#     'http://www.ft.com/content/d87f9d18-85d3-48aa-82bb-406d98f88844',
#     'http://www.ft.com/content/9567e70a-1a84-481a-861f-5b5b24487c97',
#     'https://news.google.com/articles/CAIiEDiah0Ro7Cg1OikX6EWQJbYqFggEKg0IACoGCAowt6AMMLAmMNT5lwM?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CBMiQWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2FydGljbGUvbGVnYWwtdXMtb3RjLXJpcHBsZS1pZFVTS0JOMkFHMk1K0gE0aHR0cHM6Ly9tb2JpbGUucmV1dGVycy5jb20vYXJ0aWNsZS9hbXAvaWRVU0tCTjJBRzJNSg?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiEFR5WqgmpUOwCG7ajbKkiagqGQgEKhAIACoHCAow4uzwCjCF3bsCMIrOrwM?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiEFqpC92il10oEIMKsuWITWMqGQgEKhAIACoHCAow4uzwCjCF3bsCMIrOrwM?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiEGy_ujVSPTPTCl7-sljL4V8qGQgEKhAIACoHCAowief2CjCJ2dUCMNegxwU?hl=en-US&gl=US&ceid=US%3Aen'],
#    'nounKeywords': [('labour', 2),
#     ('Sunak', 2),
#     ('Seng', 2),
#     ('index', 2),
#     ('ripple', 2),
#     ('SEC', 2),
#     ('inequality', 1),
#     ('Starmer', 1),
#     ('fix', 1),
#     ('Johnson', 1)],
#    'nerKeywords': [('Hang Seng', 2),
#     ('Ripple', 2),
#     ('SEC', 2),
#     ('Sunak', 1),
#     ('Labour', 1),
#     ('Starmer', 1),
#     ('Johnson', 1),
#     ('Coinbase', 1),
#     ('Craig Wright', 1),
#     ('UK', 1)],
#    'cluster': 6},
#   {'total_number_of_articles': 8,
#    'keywords': [],
#    'sources': ['Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'Financial Times',
#     'South China Morning Post',
#     'South China Morning Post'],
#    'dates': ['2021-02-17',
#     '2021-03-07',
#     '2021-03-03',
#     '2021-02-19',
#     '2021-03-03',
#     '2021-02-17',
#     '2021-03-16',
#     '2021-03-15'],
#    'articles': ['The equivalence tussle is giving UK a lesson in Brexit power politics ',
#     'The politics of the levelling-up agenda',
#     'A tactical Budget that spends today and taxes tomorrow',
#     'Letter: Taking back control ‘on land and sea’',
#     'The first task of democracies is to put their own house in order',
#     'The equivalence tussle is giving UK a lesson in Brexit power politics ',
#     'Election Committee to control majority of seats in revamped Legco: top official',
#     'In patriot-governed Hong Kong, ‘one country, two systems’ is assured'],
#    'urls': ['http://www.ft.com/content/3a7bc26f-80e8-474a-a374-52882d0930fe',
#     'http://www.ft.com/content/d29049ac-a47b-409f-a39c-8af59f1ec281',
#     'http://www.ft.com/content/bcb24aae-c052-4b70-a8bf-7fc9a716b46c',
#     'http://www.ft.com/content/7463fa35-6970-43a3-b8a0-e64f38dd4ddf',
#     'http://www.ft.com/content/712ec778-fd6e-4d10-96ba-a321fce1f17d',
#     'http://www.ft.com/content/3a7bc26f-80e8-474a-a374-52882d0930fe',
#     'https://news.google.?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.com/articles/CAIiENDOCWhI28K9zJaIKciDZQEqGQgEKhAIACoHCAowief2CjCJ2dUCMNegxwU?hl=en-US&gl=US&ceid=US%3Aen'],
#    'nounKeywords': [('politic', 3),
#     ('equivalence', 2),
#     ('tussle', 2),
#     ('UK', 2),
#     ('lesson', 2),
#     ('Brexit', 2),
#     ('power', 2),
#     ('level', 1),
#     ('agenda', 1),
#     ('budget', 1)],
#    'nerKeywords': [('UK', 2),
#     ('Brexit', 2),
#     ('Budget', 1),
#     ('Election Committee', 1),
#     ('Legco', 1),
#     ('Hong Kong', 1)],
#    'cluster': 7},
#   {'total_number_of_articles': 4,
#    'keywords': [],
#    'sources': ['Financial Times',
#     'Financial Times',
#     'Reuters',
#     'South China Morning Post'],
#    'dates': ['2021-03-04', '2021-03-08', '2021-03-16', '2021-03-17'],
#    'articles': ['Brussels’ Covid travel pass runs into early turbulence',
#     'Hong Kong’s Jardine to restructure after decades of pressure',
#     'Breakingviews - Jardine restructuring could tempt an activist',
#     'Truck crashes through railings on Lantau Island; firefighters rescue driver, passengers'],
#    'urls': ['http://www.ft.com/content/aeb5f939-7dad-4092-9f51-6c48967c7aa0',
#     'http://www.ft.com/content/03924f80-8600-427b-8d13-d5c890f39ffc',
#     'https://news.google.?hl=en-US&gl=US&ceid=US%3Aen',
#     'https://news.google.?hl=en-US&gl=US&ceid=US%3Aen'],
#    'nounKeywords': [('Jardine', 2),
#     ('Brussels', 1),
#     ('Covid', 1),
#     ('travel', 1),
#     ('run', 1),
#     ('turbulence', 1),
#     ('Hong', 1),
#     ('Kong', 1),
#     ('decade', 1),
#     ('pressure', 1)],
#    'nerKeywords': [('Brussels', 1),
#     ('Hong Kong’s', 1),
#     ('Jardine', 1),
#     ('Breakingviews - Jardine', 1),
#     ('Lantau Island', 1)],
#    'cluster': 8},
#   {'total_number_of_articles': 1,
#    'keywords': [],
#    'sources': ['Financial Times'],
#    'dates': ['2021-02-23'],
#    'articles': ['Aviva: Blanc cheque'],
#    'urls': ['http://www.ft.com/content/f3ea1a96-239a-41ff-b3b9-d42d35b88268'],
#    'nounKeywords': [('Aviva', 1), ('Blanc', 1)],
#    'nerKeywords': [('Blanc', 1)],
#    'cluster': 9},
#   {'total_number_of_articles': 1,
#    'keywords': [],
#    'sources': ['South China Morning Post'],
#    'dates': ['2021-03-16'],
#    'articles': ['The domestic helper’s living quarters at the centre of a ‘shed-storm’'],
#    'urls': ['https://news.google.?hl=en-US&gl=US&ceid=US%3Aen'],
#    'nounKeywords': [('helper', 1),
#     ('quarter', 1),
#     ('centre', 1),
#     ('storm', 1)],
#    'nerKeywords': [],
#    'cluster': 10}],
#  'total_number_of_articles': 560,
#  'total_number_of_clusters': 10,
#  'cluster_type': 'all',
#  'date': '2021-01-05',
#  'week': None,
#  'month': None}
